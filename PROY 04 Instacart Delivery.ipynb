# %% [markdown]
# <b>Hola Francisco</b>
#
# Mi nombre es Alejandro Abia y tengo el gusto de revisar tu proyecto.
#
# A continuación, encontrarás mis comentarios en celdas pintadas de tres colores (verde, amarillo y rojo), a manera de semáforo. Por favor, <b>no las borres ni muevas de posición</b> mientras dure el proceso de revisión.
#
# <div class="alert alert-block alert-success">
# <b>Éxito</b> <a class="tocSkip"></a>
# En celdas verdes encontrarás comentarios en relación a tus aciertos y fortalezas.
# </div>
# <div class="alert alert-block alert-warning">
# <b>Antención</b> <a class="tocSkip"></a>
# Utilizaré el color amarillo para llamar tu atención, expresar algo importante o compartirte alguna idea de valor.
# </div>
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
# En rojo emitiré aquellos puntos que deberás atender para aprobar la revisión.
# </div>
# <div class="alert alert-block alert-info">
# <b>Comentario estudiante</b><a class="tocSkip"></a>
# Es factible que, a lo largo del proceso de revisión, quieras dejarme comentarios. Si es el caso, por favor realízalo dentro de celdas azules como esta.
# </div>
# Respecto del proceso de revisión, tu proyecto será aceptado una vez que los comentarios en rojo hayan sido atendidos.
# ¡Empecemos!

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
# Realizar la importación de librerías pandas. Leer cada uno de los dataframes, usando el separador ";" y observar con info un resumane de la información contenida en cada dataframe.

# %%
import pandas as pd# importar librerías

# %%
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep = ';')
products = pd.read_csv('/datasets/products.csv', sep = ';')
aisle = pd.read_csv('/datasets/aisles.csv', sep = ';')
departments = pd.read_csv('/datasets/departments.csv', sep = ';')
order_products = pd.read_csv('/datasets/order_products.csv', sep = ';')# leer conjuntos de datos en los DataFrames

# %%
instacart_orders.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
products.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
aisle.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
departments.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
order_products.info(show_counts=True)# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Celdas [3–9]</b> <a class="tocSkip"></a><br>
# Excelente trabajo en la descripción inicial de los datos, Francisco. Lograste cargar correctamente todos los datasets, identificar los tipos de datos y anticipar observaciones relevantes sobre su estructura, como la conveniencia de mantener los IDs como enteros. Muy buena atención al detalle desde el principio.
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# En los diferentes DataFrames se observan los tipos de datos entero para los valores de identificación(id), de diferentes tipos como: product_id, user_id, etc. siendo estos valores, únicos y que no tienen una función más que la identificar un dato, no requerirán ser usados para operaciones matemáticas, por lo que pudieran ser tipo object y aún cumplirán su función; sin embargo es recomendable mantenerlos como enteros.
# Otros como days_since_prior_order, pudieran funcionar mejor como entero que como flotante. Igualmente con add_to_cart_order.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Antes de procesar dataframes es immportante verificar si hay valores nulos o ausentes de tal forma que se observa cada uno con tal de decidir si se eliminan, reemplazan y con qué se podrian reemplazar dependeiendo de la cantidad, tipo de valor ausente, etc.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders.duplicated().sum()) 
duplicados = instacart_orders.duplicated()
print(instacart_orders[duplicados])# Revisa si hay pedidos duplicados
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# Todos tienen el mismo día y la misma hora de pedido.

# %%
order_wed_2am = instacart_orders.query('order_dow == 3 and order_hour_of_day == 2')# Basándote en tus hallazgos
print(order_wed_2am)
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
# Los 15 datos duplicados se econtraban dentro de este grupo de datos, probablemente debido a algún error en la captura de estos durante ese día y horario específicos.

# %%
instacart_orders.drop_duplicates(inplace=True)# Elimina los pedidos duplicados

# %%
instacart_orders.duplicated().sum()# Vuelve a verificar si hay filas duplicadas
# Out:
# 0

# %%
print(instacart_orders['order_id'].duplicated())# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(instacart_orders['order_id'].duplicated().sum())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 478962    False
# 478963    False
# 478964    False
# 478965    False
# 478966    False
# Name: order_id, Length: 478952, dtype: bool
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Al observar que eran únicamente 15 filas duplicadas, y considerando la cantidad de datos del dataframe, se optó por eliminar tales datos ya que no es un número significativo. Para los valores que identifican cada pedido no se observan duplicados lo que indica que realmente cada fila es un único pedido.

# %% [markdown]
# ### `products` data frame

# %%
print(products.duplicated())
print(products.duplicated().sum())# Verifica si hay filas totalmente duplicadas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# 49693    False
# Length: 49694, dtype: bool
# 0

# %%
print(products['department_id'].unique())
print(products['department_id'].duplicated().sum())# Revisa únicamente si hay ID de departamentos duplicados
# Out:
# [19 13  7  1 11 16 17 18 12  9  8 14 15  4 21  6 20  5  3  2 10]
# 49673

# %%
products['product_name'] = products['product_name'].str.upper()
print(products['product_name'])
products['product_name'].duplicated().sum()# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
# Out:
# 0                               CHOCOLATE SANDWICH COOKIES
# 1                                         ALL-SEASONS SALT
# 2                     ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3        SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4                                GREEN CHILE ANYTIME SAUCE
#                                ...
# 49689                        HIGH PERFORMANCE ENERGY DRINK
# 49690                        ORIGINAL PANCAKE & WAFFLE MIX
# 49691      ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692                               SPRING WATER BODY WASH
# 49693                              BURRITO- STEAK & CHEESE
# Name: product_name, Length: 49694, dtype: object
# 1361

# %%
print(products['product_name'].isna().sum())
products[(products['product_name'].notna()) & (products['product_name'].duplicated())]## Revisa si hay nombres duplicados de productos no faltantes
# Out:
# 1258
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# ...

# %%
products.drop_duplicates(subset='product_name')
# Out:
#        product_id                                       product_name  \
# 0               1                         CHOCOLATE SANDWICH COOKIES
# 1               2                                   ALL-SEASONS SALT
# 2               3               ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3               4  SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4               5                          GREEN CHILE ANYTIME SAUCE
# ...           ...                                                ...
# 49683       49684          VODKA- TRIPLE DISTILLED- TWIST OF VANILLA
# 49684       49685                 EN CROUTE ROAST HAZELNUT CRANBERRY
# 49685       49686                                   ARTISAN BAGUETTE
# 49686       49687         SMARTBLEND HEALTHY METABOLISM DRY CAT FOOD
# 49687       49688                             FRESH FOAMING CLEANSER
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Los datos de department_id se observan duplicados en gran cantidad, sin embargo es natural ya que hay diversos productos en un departamento. Lo mismo pasaria con los pasillos. Sin embargo, se encontraron aproximadamente 1360 valores duplicados de nombres de producto, incluidos los valores nulos, considerando la cantidad de datos del dataframe se decidió eliminarlos para poder realizar el análisis con el resto de los datos que son considerablemente la mayor proporción de datos. No se encontraron filas duplicadas lo que indica que realmente el cada fila es un único producto.

# %% [markdown]
# ### `departments` data frame

# %%
print(departments.duplicated().sum())
# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(departments['department'].duplicated().sum())
# Out:
# 0

# %%
print(products['product_id'].duplicated().sum())# Revisa únicamente si hay IDs duplicadas de productos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#
# No se observan filas duplicadas en la base de datos departments, por lo que cada fila corresponde a un único departamento. E igualmente, no se observan duplicados de product_id, por lo que cada fila corresponde a un producto como dice la descripción.

# %% [markdown]
# ### `aisles` data frame

# %%
print(aisle.duplicated().sum())
# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(aisle['aisle_id'].duplicated().sum())
aisle['aisle'].duplicated()# Revisa únicamente si hay IDs duplicadas de pasillos
# Out:
# 0
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# Name: aisle, Length: 134, dtype: bool

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se observan filas duplicadas ni aisle_id duplicados de pasillos, lo que muestra un DataFrame limpio.

# %% [markdown]
# ### `order_products` data frame

# %%
print(order_products.duplicated().sum()) # Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(order_products['order_id'].duplicated().sum())
print(order_products['add_to_cart_order'].duplicated().sum())
print(order_products.sample(10))# Vuelve a verificar si hay cualquier otro duplicado engañoso
# Out:
# 4094961
# 4544942
#          order_id  product_id  add_to_cart_order  reordered
# 956036    1488516       40706                3.0          1
# 4383222   2602739       24852                2.0          1
# 1141745   2982659       30060               15.0          0
# 1859274   1754482       34969               13.0          1
# 2988142   2249088       14328               29.0          1
# 3739735   1277531       16830               11.0          0
# 1180489   2060683       21903                3.0          1
# 1309958   2768449       47873                4.0          1
# 499224    2564844       24852                6.0          1
# 1845675   1636501       37691                3.0          1

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No contiene filas de valores duplicadas y cada columna en el dataframe puede soportar duplicados, considerando que por lo que es un dataframe limpio. A excepción de unos cuantos valores nulos en add_to_cart_order.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
print(products['product_name'].isna().sum())
# Encuentra los valores ausentes en la columna 'product_name'
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Únicamente se encuentran 1258 valores ausentes o nulos, como se observó al usar el método isna() con sum(). Igualmente se observa con info().

# %%
products_nan = products[(products['product_name'].isna()) & (products['aisle_id'] == 100)]
print(products_nan.sample(10))#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
# Out:
#        product_id product_name  aisle_id  department_id
# 39282       39283          NaN       100             21
# 39025       39026          NaN       100             21
# 33292       33293          NaN       100             21
# 19431       19432          NaN       100             21
# 8800         8801          NaN       100             21
# 24721       24722          NaN       100             21
# 30184       30185          NaN       100             21
# 19091       19092          NaN       100             21
# 37883       37884          NaN       100             21
# 35134       35135          NaN       100             21

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los valores ausentes en product_name se encuentran en el pasillo 100, por que la falta de estos se infiere es una cuestión inherente a este pasillo en particular.

# %%
products_nan21 = products[(products['product_name'].isna()) & (products['department_id'] == 21)]
print(products_nan21)
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Todos los valores ausentes se encuentra en el pasillo 21.

# %%
aisle_100 = aisle[(aisle['aisle_id'] == 100) & (aisle['aisle'])]
print(aisle_100)

department_21 = departments[(departments['department_id'] == 21) & (departments['department'])]
print(department_21)
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Al parecer la información del pasillo 100 y el departamento 21, no se encuentra, por pérdida de información u otro motivo. Quizá restructuración de los mismos fisicamente.

# %%
products['product_name'] = products['product_name'].fillna('unknown')
print(products['product_name'].isna().sum())
print(products['product_name']) # Completa los nombres de productos ausentes con 'Unknown'
# Out:
# 0
# 0                               CHOCOLATE SANDWICH COOKIES
# 1                                         ALL-SEASONS SALT
# 2                     ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3        SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4                                GREEN CHILE ANYTIME SAUCE
#                                ...
# 49689                        HIGH PERFORMANCE ENERGY DRINK
# 49690                        ORIGINAL PANCAKE & WAFFLE MIX
# 49691      ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692                               SPRING WATER BODY WASH
# 49693                              BURRITO- STEAK & CHEESE
# Name: product_name, Length: 49694, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Celdas [17–31]</b> <a class="tocSkip"></a><br>
# Una sugerencia para futuras ocasiones: al reemplazar valores ausentes como en `days_since_prior_order`, podrías explorar también la imputación condicional (por ejemplo, por media o mediana según el `order_number` o segmento de usuario) para una imputación más precisa y contextualizada si el análisis lo requiere.
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Al detectar que la ausencia de información se deriva desde un departamento y un pasillo en particular, se usa "unknown" para rellenar los valores ausentes y no perder información que pudiera ser de utilidad.

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders.isna())
print(instacart_orders.isna().sum())# Encuentra los valores ausentes
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          False    False         False      False              False
# 1          False    False         False      False              False
# 2          False    False         False      False              False
# 3          False    False         False      False              False
# 4          False    False         False      False              False
# ...          ...      ...           ...        ...                ...
# 478962     False    False         False      False              False
# 478963     False    False         False      False              False
# 478964     False    False         False      False              False
# 478965     False    False         False      False              False
# 478966     False    False         False      False              False
#
#         days_since_prior_order
# 0                        False
# 1                        False
# ...

# %%
days_betwen_orders_mean = instacart_orders['days_since_prior_order'].mean()
print(days_betwen_orders_mean)
instacart_orders['days_since_prior_order'] = instacart_orders['days_since_prior_order'].fillna(days_betwen_orders_mean)
print(instacart_orders['days_since_prior_order'].isna().sum())
# Out:
# 11.101813900274362
# 0

# %%
print(instacart_orders[(instacart_orders['order_number'].isna()) & (instacart_orders['order_number'] != 1)])
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Al detectar una cantidad considerable de valores nulos en la columna de los días transcurridos entre pedidos, se decidió rellenarlos con la media esperando contar con esos datos para tener un análisis mas representativo. SIempre que la distribusión no se vea afectada pudiera ser funcional.

# %% [markdown]
# ### `order_products` data frame

# %%
order_products.isna().sum()# Encuentra los valores ausentes
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
print(order_products['add_to_cart_order'].min())
print(order_products['add_to_cart_order'].max())
order_products['add_to_cart_order'].unique()
# ¿Cuáles son los valores mínimos y máximos en esta columna?
# Out:
# 1.0
# 64.0
# array([17.,  1., 35.,  5.,  4., 10., 14.,  2., 28.,  3., 16.,  8.,  7.,
#         6.,  9., 15., 22., 49., 19., 13., 11., 12., 18., 24., 23., 45.,
#        30., 31., 29., 21., 38., 20., 57., 58., 26., 25., 39., 34., 40.,
#        27., nan, 43., 33., 42., 50., 32., 36., 37., 61., 46., 56., 41.,
#        44., 55., 54., 47., 63., 48., 60., 62., 53., 59., 52., 51., 64.])

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Existen pedidos desde uno hasta 64 artículos.

# %%
add_to_cart_nan = order_products[order_products['add_to_cart_order'].isna()]
add_to_cart_order = add_to_cart_nan['order_id']
print(add_to_cart_order)# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
# Out:
# 737        2449164
# 9926       1968313
# 14394      2926893
# 16418      1717990
# 30114      1959075
#             ...
# 4505662    1800005
# 4511400    1633337
# 4517562     404157
# 4534112    1673227
# 4535739    1832957
# Name: order_id, Length: 836, dtype: int64

# %%
order_products_filtered = order_products[order_products['add_to_cart_order'].isna()]
order_id_nan = order_products_filtered.groupby('order_id')['product_id'].count()
print(order_id_nan.sort_values())

# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
# Out:
# order_id
# 9310        1
# 747668      1
# 1598369     1
# 1677118     1
# 2170451     1
#            ..
# 1959075    34
# 171934     40
# 2136777    44
# 3308010    51
# 61355      63
# Name: product_id, Length: 70, dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Todos los pedidos tienen menos de 64 productos.

# %%
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna('999').astype(int)
print(order_products['add_to_cart_order'].isna().sum())
order_products.info()
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Celdas [10–39]</b> <a class="tocSkip"></a><br>
# La limpieza de datos es muy sólida: eliminaste duplicados de manera fundamentada, corregiste valores ausentes con criterio según el contexto, y dejaste los DataFrames listos para su análisis posterior. El manejo cuidadoso de los valores nulos en `products`, `orders` y `order_products` demuestra madurez técnica.
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se observaron 836 valores nulos en add_to_cart_order, los cuáles fueron reemplazados por un valor y convertidos en enteros de tal forma se puedan conservar las filas para poder analisis posteriores. Igualmente el manejo nde estos datos en enteros, pemitirá realizar análisis más exactos.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos.
#
# En la base de datos de pedidos realizados en la aplicación se eliminaron las 15 filas duplicadas, las cuales eran una cantidad mínima en consideración de la cantidad de filas totales. Igualmente se verifico que las filas realmente representaran un pedido individual en cada una de ellas.
#
# En la base de productos, se verificó que cada fila corresponda a un producto único mediante la verificación de la ausencia de valores duplicados. A excepción de los valores duplicados de los nombres de los productos, que ya no aseguraba que la base contuviera realmente una fila por producto, por lo que fueron eliminados. Cabe mencionar que era un cantidad mínima la que se presentaba.
#
# Las bases de pasillos y de departamentos cumplen eficazmente su función al no presentar valores duplicados.
#
# Igualmente se analizó la presencia de valores ausentes, eliminando los valores que no influirían en un análisis mas profundo por su cantidad ínfima, y reemplazando tales que por su cantidad, no sería claro decir si afectará en el análisis posteriores, hasta tener análisis estadísticos.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
instacart_orders['order_hour_of_day'].describe()
# Out:
# count    478952.000000
# mean         13.447034
# std           4.224567
# min           0.000000
# 25%          10.000000
# 50%          13.000000
# 75%          16.000000
# max          23.000000
# Name: order_hour_of_day, dtype: float64

# %%
instacart_orders['order_dow'].describe()
# Out:
# count    478952.000000
# mean          2.775051
# std           2.045901
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max           6.000000
# Name: order_dow, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones.
#
# Como es de esperarse los valores para horas del día, son 24 y para los días de la semana son 6.

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
import numpy as np
from matplotlib import pyplot as plt
hour_day_people = instacart_orders.groupby('order_hour_of_day')['user_id'].count()
hour_day_people.plot(title='Número de compras por hora del día', xlabel='Horas del día', ylabel='Cantidad de pedidos', kind='bar', color='purple')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La personas empiezana  hacer sus compras a aprtor de las 7 a 8 horas, manteniendose constante una alta demanda entre las 9 y 16 horas, empezando a descender posteriormente de manera regularizada, es decir, poco a poco.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
day_order = instacart_orders.groupby('order_dow')['user_id'].count()
day_order.plot(title='Número de compras por día de la semana', xlabel='Días de la semana(domingo a sábado)', ylabel='Cantidad pedidos', kind='bar')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# En términos generales la distribución de las compras es constante durante toda la semana, observandose un aumento de ligero a regular los días dsomingo y lunes.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
days_prior_next_order = instacart_orders.groupby('days_since_prior_order')['order_id'].count()
days_prior_next_order.plot(title='Días que esperan para hacer otro pedido', xlabel='Núimero de Días', ylabel='Cantidad de pedidos', kind='bar')
# Out:
# <AxesSubplot:title={'center':'Días que esperan para hacer otro pedido'}, xlabel='Núimero de Días', ylabel='Cantidad de pedidos'>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Celdas [40–44]</b> <a class="tocSkip"></a><br>
# Tus gráficos para analizar la frecuencia de compras por hora y día de la semana están muy bien planteados. Las interpretaciones que haces basándote en los resultados son claras, pertinentes y enriquecen el valor analítico del proyecto.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Las personas esperan entre a 8 días para realizar pedidos. Observando dos picos uno a los 8 días y otro a los 30 días, interesenatemente siendo este úlimo el mayor de todos. Después de la media (11 días) se observa un numer´disminuido de pedidos entre los 16 a 29 días.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
from matplotlib import pyplot as plt
io_filtered = instacart_orders[['order_hour_of_day', 'order_dow', 'order_id']] # filtrado de df original
io_4y6 = io_filtered[(io_filtered['order_dow']==4) |(io_filtered['order_dow']==6)] #filtrado para miercoles y sabado
print(io_4y6)
# Out:
#         order_hour_of_day  order_dow  order_id
# 0                      13          6   1515936
# 4                      12          4   3007858
# 9                       8          4    446014
# 10                     11          4   1162566
# 11                     16          6    102585
# ...                   ...        ...       ...
# 478943                 10          6    548902
# 478944                 23          4   2319639
# 478954                 21          6    984024
# 478958                  9          4   2814335
# 478961                 10          6   3006133
#
# [122459 rows x 3 columns]

# %%
pivot_data = io_4y6.pivot_table(index='order_hour_of_day',
                                columns='order_dow',
                                values='order_id',
                                aggfunc='count',
                               )
print(pivot_data)
# Out:
# order_dow             4     6
# order_hour_of_day
# 0                   324   464
# 1                   229   254
# 2                   114   177
# 3                   109   125
# 4                   100   118
# 5                   198   161
# 6                   594   451
# 7                  1787  1619
# 8                  3136  3246
# 9                  4332  4311
# 10                 4938  4919
# 11                 4842  5116
# 12                 4433  5132
# 13                 4567  5323
# 14                 4795  5375
# 15                 4795  5188
# 16                 4788  5029
# 17                 4089  4295
# 18                 3379  3338
# 19                 2691  2610
# 20                 2037  1847
# 21                 1506  1473
# 22                 1236  1185
# 23                  791   893

# %%
pivot_data.plot(kind='bar', title='Horas de ventas, miércoles y sábados', xlabel='Hora del día (horas)', ylabel='Cantidad de pedidos')
plt.legend(['Miércoles', 'Sábado'])

# %% [markdown]
# Podemos observar durante cada hora del día, se van incrementando los pedidos, siendo similarmente comportados para los miércoles y los sábados, observando un ligero incremento los días sábados durante las 11 y 17 horas respecto a las mismas horas de los días miércoles.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
order_client = instacart_orders.groupby('order_number')['user_id'].count()
print(order_client)
# distribución de numero de pedidos que hacen los clientes
# order_number como base
# Out:
# order_number
# 1      28817
# 2      28633
# 3      28685
# 4      28703
# 5      25661
#        ...
# 96       220
# 97       221
# 98       191
# 99       169
# 100      194
# Name: user_id, Length: 100, dtype: int64

# %%
order_client.plot(kind='bar', title='Distribución de números de pedidos por clientes', xlabel= 'Número de pedidos realizados', ylabel='Cantidad de cliente', figsize=[18, 5] )
# Out:
# <AxesSubplot:title={'center':'Distribución de números de pedidos por clientes'}, xlabel='Número de pedidos realizados', ylabel='Cantidad de cliente'>

# %% [markdown]
# Se observa claramente, la mayoría de los clientes realizan entre 1 y 5 pedidos, diminuyendo paulatinamente la cantidad de clientes conforme de va incrementando la cantidad de pedidos.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
df_group = order_products.groupby('product_id').size().reset_index(name='ventas') # agrupación y conteo de ventas de productos
df_group
# Out:
#        product_id  ventas
# 0               1     280
# 1               2      11
# 2               3      42
# 3               4      49
# 4               7       2
# ...           ...     ...
# 45568       49690       5
# 45569       49691      72
# 45570       49692      12
# 45571       49693      25
# 45572       49694       9
#
# [45573 rows x 2 columns]

# %%
df_20max = df_group.merge(products[['product_name', 'product_id']], on='product_id', how='left')
df_20max = df_20max.sort_values(by='ventas', ascending=False).head(20) 
df_20max
# Out:
#        product_id  ventas              product_name
# 22808       24852   66050                    BANANA
# 12025       13176   53297    BAG OF ORGANIC BANANAS
# 19370       21137   37039      ORGANIC STRAWBERRIES
# 20077       21903   33971      ORGANIC BABY SPINACH
# 43271       47209   29773      ORGANIC HASS AVOCADO
# 43788       47766   24689           ORGANIC AVOCADO
# 43663       47626   21495               LARGE LEMON
# 15364       16797   20018              STRAWBERRIES
# 24047       26209   19690                     LIMES
# 25556       27845   19600        ORGANIC WHOLE MILK
# 25666       27966   19197       ORGANIC RASPBERRIES
# 21025       22935   15898      ORGANIC YELLOW ONION
# 22908       24964   15292            ORGANIC GARLIC
# 41244       45007   14584          ORGANIC ZUCCHINI
# 35996       39275   13879       ORGANIC BLUEBERRIES
# 45561       49683   13675            CUCUMBER KIRBY
# 25889       28204   12544        ORGANIC FUJI APPLE
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Celdas [45–51]</b> <a class="tocSkip"></a><br>
# El análisis comparativo entre miércoles y sábados, así como la identificación de los productos más populares, están correctamente ejecutados. Me gustó especialmente que organizaste de manera clara las tablas de resultados y priorizaste el cruce de datos para agregar nombres de productos. ¡Muy buen nivel de detalle!
# </div>

# %% [markdown]
# Los productos más vendidos correponden a comestibles, específicamente alimentos orgánicos.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
op_group2 = order_products.groupby('order_id').size().reset_index(name='product_num') 
op_group2 = op_group2.sort_values('product_num')
op_group2 
# cauntos product_id hay en cada order_id
# cuantos products_id o maximo número secuencial por order_id
# Out:
#         order_id  product_num
# 450045   3421079            1
# 169251   1288686            1
# 169263   1288764            1
# 169270   1288825            1
# 169274   1288873            1
# ...          ...          ...
# 257945   1959075           98
# 22701     171934          104
# 281303   2136777          108
# 435088   3308010          115
# 8201       61355          127
#
# [450046 rows x 2 columns]

# %%
op_group_mean = op_group2['product_num'].mean() 
op_group_mean
# Out:
# 10.098983215049127

# %%
op_group2['product_num'].plot(kind='hist', title='Distribución de productos por pedido', bins=100, figsize=[10, 10], xlabel='Número de productos')
plt.legend(['cantidad de pedidos'])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Celdas [94–113]</b> <a class="tocSkip"></a><br>
# El análisis sobre el número de artículos por pedido y su distribución es muy valioso. La interpretación de los picos y la tendencia decreciente en la cantidad de artículos fue clara y basada en los datos observados. Excelente criterio analítico en la sección avanzada del proyecto.
# </div>

# %% [markdown]
# La gran mayoría de pedidos se hace con 1 a 10 artículos, con al gunos picos quizá en 1, 5 y 10 artículos. Continua disminuyendo con un pico interesasnte alrededor de los 15 artículos.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
pedx2 = order_products[order_products['reordered'] == 1]
pedx2

# articulos con reordered 1
# los 20 que más aparecen en order_id
# de los articulos repedidos , cuales product_id aparecen mas en los pedidos order_id
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 3          491251        8670                 35          1
# 4         2571142        1940                  5          1
# 5         2456893       21616                  4          1
# ...           ...         ...                ...        ...
# 4544999   1622300       24852                  1          1
# 4545000   1125324       40600                  6          1
# 4545002    577211       15290                 12          1
# 4545004    692640       47766                  4          1
# 4545005    319435         691                  8          1
#
# [2683838 rows x 4 columns]

# %%
pedx2 = pedx2.groupby('product_id').size().reset_index(name='num_ventas2')

pedx2
# Out:
#        product_id  num_ventas2
# 0               1          158
# 1               3           31
# 2               4           25
# 3               7            1
# 4               8            6
# ...           ...          ...
# 36223       49690            4
# 36224       49691           31
# 36225       49692            5
# 36226       49693           11
# 36227       49694            3
#
# [36228 rows x 2 columns]

# %%
ped_20max2 = pedx2.merge(products[['product_name', 'product_id']], on='product_id', how='left')
ped_20max2 = ped_20max2.sort_values(by='num_ventas2', ascending=False).head(20) 
ped_20max2
# Out:
#        product_id  num_ventas2              product_name
# 18104       24852        55763                    BANANA
# 9528        13176        44450    BAG OF ORGANIC BANANAS
# 15368       21137        28639      ORGANIC STRAWBERRIES
# 15936       21903        26233      ORGANIC BABY SPINACH
# 34407       47209        23629      ORGANIC HASS AVOCADO
# 34828       47766        18743           ORGANIC AVOCADO
# 20285       27845        16251        ORGANIC WHOLE MILK
# 34725       47626        15044               LARGE LEMON
# 20375       27966        14748       ORGANIC RASPBERRIES
# 12193       16797        13945              STRAWBERRIES
# 19088       26209        13327                     LIMES
# 16700       22935        11145      ORGANIC YELLOW ONION
# 18186       24964        10411            ORGANIC GARLIC
# 32792       45007        10076          ORGANIC ZUCCHINI
# 36219       49683         9538            CUCUMBER KIRBY
# ...

# %% [markdown]
# Los artículos mas pedidos, dentro de los artículos que ya han sido pedidso previamente, se observan productos comestibles orgánicos, interesante observar que concuerdan con los más vendidos, probablemente observación esperada.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
pedx1 = order_products[order_products['reordered'] == 0]
pedx1
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440                 17          0
# 11          44064       22963                 28          0
# 13        2475670       48520                  3          0
# 18          89640       46692                  7          0
# 21        2905625       26209                  2          0
# ...           ...         ...                ...        ...
# 4544995    635380       28849                 11          0
# 4544997   2300092       10017                  1          0
# 4545001   2179020       10902                 23          0
# 4545003   1219554       21914                  9          0
# 4545006   1398151       28733                  9          0
#
# [1861169 rows x 4 columns]

# %%
pedx1 = pedx1.groupby('product_id').size().reset_index(name='num_ventas1').sort_values(by='num_ventas1', ascending=False)
pedx1
# Out:
#        product_id  num_ventas1
# 21918       24852        10287
# 11558       13176         8847
# 18600       21137         8400
# 19288       21903         7738
# 41925       47626         6451
# ...           ...          ...
# 25118       28478            1
# 20953       23771            1
# 11974       13638            1
# 18840       21402            1
# 9619        10954            1
#
# [43764 rows x 2 columns]

# %%
ped_x = pedx1.merge(pedx2[['product_id', 'num_ventas2']], on='product_id', how='left')
ped_x = ped_x.sort_values(by='product_id', ascending=True) 
ped_x
# Out:
#        product_id  num_ventas1  num_ventas2
# 2937            1          122        158.0
# 16741           2           11          NaN
# 16949           3           11         31.0
# 10832           4           24         25.0
# 38677           7            1          1.0
# ...           ...          ...          ...
# 38680       49690            1          4.0
# 7559        49691           41         31.0
# 20854       49692            7          5.0
# 15171       49693           14         11.0
# 23678       49694            6          3.0
#
# [43764 rows x 3 columns]

# %%
ped_x['rate'] = (ped_x['num_ventas1']+ped_x['num_ventas2'])/(ped_x['num_ventas1'])
ped_x['rate']
# Out:
# 2937     2.295082
# 16741         NaN
# 16949    3.818182
# 10832    2.041667
# 38677    2.000000
#            ...
# 38680    5.000000
# 7559     1.756098
# 20854    1.714286
# 15171    1.785714
# 23678    1.500000
# Name: rate, Length: 43764, dtype: float64

# %%
ped_rate = ped_x.merge(products[['product_id', 'product_name']], on='product_id', how='left')
ped_rate = ped_rate.sort_values(by='product_id', ascending=True) 
print(ped_rate)
ped_rate['rate'].describe()
# Out:
#        product_id  num_ventas1  num_ventas2      rate  \
# 0               1          122        158.0  2.295082
# 1               2           11          NaN       NaN
# 2               3           11         31.0  3.818182
# 3               4           24         25.0  2.041667
# 4               7            1          1.0  2.000000
# ...           ...          ...          ...       ...
# 43759       49690            1          4.0  5.000000
# 43760       49691           41         31.0  1.756098
# 43761       49692            7          5.0  1.714286
# 43762       49693           14         11.0  1.785714
# 43763       49694            6          3.0  1.500000
#
#                                             product_name
# 0                             CHOCOLATE SANDWICH COOKIES
# 1                                       ALL-SEASONS SALT
# 2                   ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3      SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Celdas [55–62]</b> <a class="tocSkip"></a><br>
# Muy buen cálculo de la tasa de repetición de productos y su interpretación. Como sugerencia para proyectos futuros, podrías representar gráficamente las tasas de repetición más altas (por ejemplo, top 20) en un gráfico de barras o scatter plot para hacer los hallazgos aún más intuitivos visualmente.
# </div>

# %% [markdown]
# Se obervan artículos que se han vuelto a pedir desde una sola vez más, hasta 5 veces más, siendo la distibución que hasta eñ 75% de los productos se han pedido 2.5 veces más.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
pivot_data = order_products.pivot_table (index='order_id',
                                         columns='reordered',
                                         values='product_id',
                                         aggfunc='count'
                                        )
pivot_data
# Out:
# reordered    0     1
# order_id
# 4          1.0  12.0
# 9          5.0  10.0
# 11         NaN   5.0
# 19         NaN   3.0
# 20         8.0   NaN
# ...        ...   ...
# 3421034    NaN  17.0
# 3421053    NaN   9.0
# 3421071    4.0   1.0
# 3421077    4.0   NaN
# 3421079    1.0   NaN
#
# [450046 rows x 2 columns]

# %%
pivot_data.plot(kind='hist', bins=60, alpha= 0.5, xlim=[0, 30], title='Distribución de pedidos y nuevos pedidos', xlabel='Número de productos pedidos')
plt.legend(['1er Pedido', '2do Pedido'])
plt.show()

# %% [markdown]
# Los clientes piden en mayor proporción los mismos articulos en el segundo pedido. Sin embargo existen artículos que se piden en un primer pedido y no en el segundo y viceversa.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_20_first_added = order_products[order_products['add_to_cart_order'] == 1]
first_20_first_added
# add_to_cart_ que sea 1
# conteo de user_id por product_id
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 14        1961225       37553                  1          1
# 16         639939       10017                  1          1
# 23         750040        8518                  1          0
# ...           ...         ...                ...        ...
# 4544978   1759009       46175                  1          0
# 4544989    115427       20842                  1          1
# 4544990   2049780       28576                  1          1
# 4544997   2300092       10017                  1          0
# 4544999   1622300       24852                  1          1
#
# [450046 rows x 4 columns]

# %%
first_20_first_added = first_20_first_added.groupby('product_id').size().reset_index(name='products_quant')
first_20_first_added
# Out:
#        product_id  products_quant
# 0               1              47
# 1               2               2
# 2               3               5
# 3               4               1
# 4               8               4
# ...           ...             ...
# 26755       49687               1
# 26756       49688               1
# 26757       49690               2
# 26758       49691               3
# 26759       49693               3
#
# [26760 rows x 2 columns]

# %%
first_20_first_added = first_20_first_added.merge(products[['product_id', 'product_name']], on='product_id', how='left')
first_20_first_added = first_20_first_added.sort_values(by='products_quant', ascending=False) 
first_20_first_added
# Out:
#        product_id  products_quant                            product_name_x  \
# 26759       24852           15562                                    BANANA
# 26758       13176           11026                    BAG OF ORGANIC BANANAS
# 26757       27845            4363                        ORGANIC WHOLE MILK
# 26756       21137            3946                      ORGANIC STRAWBERRIES
# 26755       47209            3390                      ORGANIC HASS AVOCADO
# ...           ...             ...                                       ...
# 5568         2840               1                   ORIGINAL A TO Z'S PASTA
# 5569        43121               1  GOURMET NATURAL ORIGINAL MAGIC SEASONING
# 5570        49252               1       HAIRBALL CARE WITH CHICKEN CAT FOOD
# 5571         2841               1                            8 HOT DOG BUNS
# 0           24786               1          NO MORE TANGLES DETANGLING SPRAY
#
#                                  product_name_y
# ...

# %% [markdown]
# Los principales productos son comestibles, naturalñes y orgánicos.

# %% [markdown]
# ### Conclusion general del proyecto:
#
# Las bases de datos contienen información bastante completa que permite obtener resultados muy cercanos a la realidad, que con un análisis estadístico se confirmaría.
# Dentro de los puntos de importancia,la maypria de las compras se realizan durante el horario probablemente más activo de las personas, compran entre las 9 hasta las 10 horas, con un ligero incremento entre las 11 y 16 horas.
# Dentro de los días de la semana ccon mas pedidos son los domingos y lunes.
# Igualmente el número de pedidos en promedio es de 11 artículos y dentro de la cantidad de pedidos que realizan los clientes, la gran mayoría compre de 1 a 5 veces, disminuyendo paulatinamente, la cantidad de personas que realizan más pedidos.
# Observando a los artículos que se piden y se vuelven a pedir es común que se pide al menos 2 veces más el mismo artículo en posteriores pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario final</b> <a class="tocSkip"></a><br>
# ¡Excelente proyecto, Francisco! Destacas por tu enfoque estructurado, el cuidado en el preprocesamiento, la claridad en el análisis y la correcta interpretación de patrones relevantes en los datos.  ¡Sigue así, estás mostrando un dominio muy sólido en ciencia de datos!
# </div>
